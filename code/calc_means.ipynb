# %%
import os
from datetime import datetime

from core.utils import index_unit_map, index_acronym_map, index_longname_map
from core.calc_means import load_aggregate_data

# %%
save_path = '../data'
startyear = 1995
endyear = 2014

# %%
def add_metadata(ds):
    ds.attrs = {
        'title': '{}-{} mean of annual ETCCDI Extreme Indices'.format(startyear, endyear),
        'further_info': 'https://etccdi.pacificclimate.org/list_27_indices.shtml',
        'processing_scripts': 'TODO: Git',
        'source': 'MPI-ESM1-2-LR; Olonscheck et al. (2023): https://doi.org/10.1029/2023MS003790',
        'creator': 'CC BY Lukas Brunner, University of Hamburg (lukas.brunner@uni-hamburg.de; https://orcid.org/0000-0001-5760-4524)',
        'institution': 'University of Hamburg',
        'creation_date': datetime.today().strftime('%Y-%m-%d %H:%M'),
        'reference': 'TODO: paper',
    }
    return ds

# %%
for index in index_acronym_map.keys():
    ds = load_aggregate_data(index, startyear=startyear, endyear=endyear)
    ds = add_metadata(ds)
    ds.to_netcdf(os.path.join(save_path, '{}_{}-{}.nc'.format(index, startyear, endyear)))
# Out:
# Load index='txx'
# Load index='tnn'
# Load index='txn'
# Load index='tnx'
# Load index='dtr'
# Load index='tx90p'
# Load index='tn10p'
# Load index='tx10p'
# Load index='tn90p'
# Load index='wsdi'
# Load index='csdi'
# Load index='su'
# Load index='id'
# Load index='fd'
# Load index='tr'
# Load index='gsl'
# nan found in index='gsl', member='r1i1p1f1'
# nan found in index='gsl', member='r2i1p1f1'
# nan found in index='gsl', member='r3i1p1f1'
# nan found in index='gsl', member='r4i1p1f1'
# nan found in index='gsl', member='r5i1p1f1'
# nan found in index='gsl', member='r6i1p1f1'
# nan found in index='gsl', member='r7i1p1f1'
# nan found in index='gsl', member='r8i1p1f1'
# nan found in index='gsl', member='r9i1p1f1'
# nan found in index='gsl', member='r10i1p1f1'
# nan found in index='gsl', member='r11i1p1f1'
# nan found in index='gsl', member='r12i1p1f1'
# nan found in index='gsl', member='r13i1p1f1'
# nan found in index='gsl', member='r14i1p1f1'
# nan found in index='gsl', member='r15i1p1f1'
# nan found in index='gsl', member='r16i1p1f1'
# nan found in index='gsl', member='r17i1p1f1'
# nan found in index='gsl', member='r18i1p1f1'
# nan found in index='gsl', member='r19i1p1f1'
# nan found in index='gsl', member='r20i1p1f1'
# nan found in index='gsl', member='r21i1p1f1'
# nan found in index='gsl', member='r22i1p1f1'
# nan found in index='gsl', member='r23i1p1f1'
# nan found in index='gsl', member='r24i1p1f1'
# nan found in index='gsl', member='r25i1p1f1'
# nan found in index='gsl', member='r26i1p1f1'
# nan found in index='gsl', member='r27i1p1f1'
# nan found in index='gsl', member='r28i1p1f1'
# nan found in index='gsl', member='r29i1p1f1'
# nan found in index='gsl', member='r30i1p1f1'
# nan found in index='gsl', member='r31i1p1f1'
# nan found in index='gsl', member='r32i1p1f1'
# nan found in index='gsl', member='r33i1p1f1'
# nan found in index='gsl', member='r34i1p1f1'
# nan found in index='gsl', member='r35i1p1f1'
# nan found in index='gsl', member='r36i1p1f1'
# nan found in index='gsl', member='r37i1p1f1'
# nan found in index='gsl', member='r38i1p1f1'
# nan found in index='gsl', member='r39i1p1f1'
# nan found in index='gsl', member='r40i1p1f1'
# nan found in index='gsl', member='r41i1p1f1'
# nan found in index='gsl', member='r42i1p1f1'
# nan found in index='gsl', member='r43i1p1f1'
# nan found in index='gsl', member='r44i1p1f1'
# nan found in index='gsl', member='r45i1p1f1'
# nan found in index='gsl', member='r46i1p1f1'
# nan found in index='gsl', member='r47i1p1f1'
# nan found in index='gsl', member='r48i1p1f1'
# nan found in index='gsl', member='r49i1p1f1'
# nan found in index='gsl', member='r50i1p1f1'
# Load index='prcptot'
# Load index='sdii'
# nan found in index='sdii', member='r1i1p1f1'
# nan found in index='sdii', member='r2i1p1f1'
# nan found in index='sdii', member='r3i1p1f1'
# nan found in index='sdii', member='r4i1p1f1'
# nan found in index='sdii', member='r5i1p1f1'
# nan found in index='sdii', member='r6i1p1f1'
# nan found in index='sdii', member='r7i1p1f1'
# nan found in index='sdii', member='r8i1p1f1'
# nan found in index='sdii', member='r9i1p1f1'
# nan found in index='sdii', member='r10i1p1f1'
# nan found in index='sdii', member='r11i1p1f1'
# nan found in index='sdii', member='r12i1p1f1'
# nan found in index='sdii', member='r13i1p1f1'
# nan found in index='sdii', member='r14i1p1f1'
# nan found in index='sdii', member='r15i1p1f1'
# nan found in index='sdii', member='r16i1p1f1'
# nan found in index='sdii', member='r17i1p1f1'
# nan found in index='sdii', member='r18i1p1f1'
# nan found in index='sdii', member='r19i1p1f1'
# nan found in index='sdii', member='r20i1p1f1'
# nan found in index='sdii', member='r21i1p1f1'
# nan found in index='sdii', member='r22i1p1f1'
# nan found in index='sdii', member='r23i1p1f1'
# nan found in index='sdii', member='r24i1p1f1'
# nan found in index='sdii', member='r25i1p1f1'
# nan found in index='sdii', member='r26i1p1f1'
# nan found in index='sdii', member='r27i1p1f1'
# nan found in index='sdii', member='r28i1p1f1'
# nan found in index='sdii', member='r29i1p1f1'
# nan found in index='sdii', member='r30i1p1f1'
# nan found in index='sdii', member='r31i1p1f1'
# nan found in index='sdii', member='r32i1p1f1'
# nan found in index='sdii', member='r33i1p1f1'
# nan found in index='sdii', member='r34i1p1f1'
# nan found in index='sdii', member='r35i1p1f1'
# nan found in index='sdii', member='r36i1p1f1'
# nan found in index='sdii', member='r37i1p1f1'
# nan found in index='sdii', member='r38i1p1f1'
# nan found in index='sdii', member='r39i1p1f1'
# nan found in index='sdii', member='r40i1p1f1'
# nan found in index='sdii', member='r41i1p1f1'
# nan found in index='sdii', member='r42i1p1f1'
# nan found in index='sdii', member='r43i1p1f1'
# nan found in index='sdii', member='r44i1p1f1'
# nan found in index='sdii', member='r45i1p1f1'
# nan found in index='sdii', member='r46i1p1f1'
# nan found in index='sdii', member='r47i1p1f1'
# nan found in index='sdii', member='r48i1p1f1'
# nan found in index='sdii', member='r49i1p1f1'
# nan found in index='sdii', member='r50i1p1f1'
# Load index='rx1day'
# Load index='rx5day'
# Load index='cwd'
# nan found in index='cwd', member='r13i1p1f1'
# nan found in index='cwd', member='r15i1p1f1'
# nan found in index='cwd', member='r17i1p1f1'
# nan found in index='cwd', member='r20i1p1f1'
# nan found in index='cwd', member='r25i1p1f1'
# nan found in index='cwd', member='r27i1p1f1'
# nan found in index='cwd', member='r33i1p1f1'
# nan found in index='cwd', member='r34i1p1f1'
# nan found in index='cwd', member='r41i1p1f1'
# nan found in index='cwd', member='r42i1p1f1'
# nan found in index='cwd', member='r43i1p1f1'
# nan found in index='cwd', member='r45i1p1f1'
# Load index='cdd'
# nan found in index='cdd', member='r1i1p1f1'
# nan found in index='cdd', member='r2i1p1f1'
# nan found in index='cdd', member='r3i1p1f1'
# nan found in index='cdd', member='r4i1p1f1'
# nan found in index='cdd', member='r5i1p1f1'
# nan found in index='cdd', member='r6i1p1f1'
# nan found in index='cdd', member='r7i1p1f1'
# nan found in index='cdd', member='r8i1p1f1'
# nan found in index='cdd', member='r9i1p1f1'
# nan found in index='cdd', member='r10i1p1f1'
# nan found in index='cdd', member='r11i1p1f1'
# nan found in index='cdd', member='r12i1p1f1'
# nan found in index='cdd', member='r13i1p1f1'
# nan found in index='cdd', member='r14i1p1f1'
# nan found in index='cdd', member='r15i1p1f1'
# nan found in index='cdd', member='r16i1p1f1'
# nan found in index='cdd', member='r17i1p1f1'
# nan found in index='cdd', member='r18i1p1f1'
# nan found in index='cdd', member='r19i1p1f1'
# nan found in index='cdd', member='r20i1p1f1'
# nan found in index='cdd', member='r21i1p1f1'
# nan found in index='cdd', member='r22i1p1f1'
# nan found in index='cdd', member='r23i1p1f1'
# nan found in index='cdd', member='r24i1p1f1'
# nan found in index='cdd', member='r25i1p1f1'
# nan found in index='cdd', member='r26i1p1f1'
# nan found in index='cdd', member='r27i1p1f1'
# nan found in index='cdd', member='r28i1p1f1'
# nan found in index='cdd', member='r29i1p1f1'
# nan found in index='cdd', member='r30i1p1f1'
# nan found in index='cdd', member='r31i1p1f1'
# nan found in index='cdd', member='r32i1p1f1'
# nan found in index='cdd', member='r33i1p1f1'
# nan found in index='cdd', member='r34i1p1f1'
# nan found in index='cdd', member='r35i1p1f1'
# nan found in index='cdd', member='r36i1p1f1'
# nan found in index='cdd', member='r37i1p1f1'
# nan found in index='cdd', member='r38i1p1f1'
# nan found in index='cdd', member='r39i1p1f1'
# nan found in index='cdd', member='r40i1p1f1'
# nan found in index='cdd', member='r41i1p1f1'
# nan found in index='cdd', member='r42i1p1f1'
# nan found in index='cdd', member='r43i1p1f1'
# nan found in index='cdd', member='r44i1p1f1'
# nan found in index='cdd', member='r45i1p1f1'
# nan found in index='cdd', member='r46i1p1f1'
# nan found in index='cdd', member='r47i1p1f1'
# nan found in index='cdd', member='r48i1p1f1'
# nan found in index='cdd', member='r49i1p1f1'
# nan found in index='cdd', member='r50i1p1f1'
# Load index='r95p'
# Load index='r99p'
# Load index='r10mm'
# Load index='r20mm'
